# %%
import pandas as pd

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Junaid Ahmed\Artificial intelligence

# %% [markdown]
# # how to read csv file in pandas

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv')

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv',nrows=1)

# %%
df
# Out:
#    Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021                     Level 1                 99999
#
#   Industry_name_NZSIOC               Units Variable_code Variable_name  \
# 0       All industries  Dollars (millions)           H01  Total income
#
#        Variable_category    Value  \
# 0  Financial performance  757,504
#
#                               Industry_code_ANZSIC06
# 0  ANZSIC06 divisions A-S (excluding classes K633...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv',nrows=5)

# %%
df
# Out:
#    Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021                     Level 1                 99999
# 1  2021                     Level 1                 99999
# 2  2021                     Level 1                 99999
# 3  2021                     Level 1                 99999
# 4  2021                     Level 1                 99999
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv',usecols=[0,1])

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC
# 0      2021                     Level 1
# 1      2021                     Level 1
# 2      2021                     Level 1
# 3      2021                     Level 1
# 4      2021                     Level 1
# ...     ...                         ...
# 41710  2013                     Level 3
# 41711  2013                     Level 3
# 41712  2013                     Level 3
# 41713  2013                     Level 3
# 41714  2013                     Level 3
#
# [41715 rows x 2 columns]

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv',usecols=[2,4,7])

# %%
df
# Out:
#       Industry_code_NZSIOC               Units      Variable_category
# 0                    99999  Dollars (millions)  Financial performance
# 1                    99999  Dollars (millions)  Financial performance
# 2                    99999  Dollars (millions)  Financial performance
# 3                    99999  Dollars (millions)  Financial performance
# 4                    99999  Dollars (millions)  Financial performance
# ...                    ...                 ...                    ...
# 41710                 ZZ11          Percentage       Financial ratios
# 41711                 ZZ11          Percentage       Financial ratios
# 41712                 ZZ11          Percentage       Financial ratios
# 41713                 ZZ11          Percentage       Financial ratios
# 41714                 ZZ11          Percentage       Financial ratios
#
# [41715 rows x 3 columns]

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv',skiprows=1)

# %%
df
# Out:
#        2021  Level 1  99999              All industries  Dollars (millions)  \
# 0      2021  Level 1  99999              All industries  Dollars (millions)
# 1      2021  Level 1  99999              All industries  Dollars (millions)
# 2      2021  Level 1  99999              All industries  Dollars (millions)
# 3      2021  Level 1  99999              All industries  Dollars (millions)
# 4      2021  Level 1  99999              All industries  Dollars (millions)
# ...     ...      ...    ...                         ...                 ...
# 41709  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41710  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41711  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41712  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41713  2013  Level 3   ZZ11  Food product manufacturing          Percentage
#
# ...

# %%
df
# Out:
#        2021  Level 1  99999              All industries  Dollars (millions)  \
# 0      2021  Level 1  99999              All industries  Dollars (millions)
# 1      2021  Level 1  99999              All industries  Dollars (millions)
# 2      2021  Level 1  99999              All industries  Dollars (millions)
# 3      2021  Level 1  99999              All industries  Dollars (millions)
# 4      2021  Level 1  99999              All industries  Dollars (millions)
# ...     ...      ...    ...                         ...                 ...
# 41709  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41710  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41711  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41712  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41713  2013  Level 3   ZZ11  Food product manufacturing          Percentage
#
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv',skiprows=2)

# %%
df
# Out:
#        2021  Level 1  99999              All industries  Dollars (millions)  \
# 0      2021  Level 1  99999              All industries  Dollars (millions)
# 1      2021  Level 1  99999              All industries  Dollars (millions)
# 2      2021  Level 1  99999              All industries  Dollars (millions)
# 3      2021  Level 1  99999              All industries  Dollars (millions)
# 4      2021  Level 1  99999              All industries  Dollars (millions)
# ...     ...      ...    ...                         ...                 ...
# 41708  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41709  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41710  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41711  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41712  2013  Level 3   ZZ11  Food product manufacturing          Percentage
#
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv')

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv',skiprows=[0])

# %%
df
# Out:
#        2021  Level 1  99999              All industries  Dollars (millions)  \
# 0      2021  Level 1  99999              All industries  Dollars (millions)
# 1      2021  Level 1  99999              All industries  Dollars (millions)
# 2      2021  Level 1  99999              All industries  Dollars (millions)
# 3      2021  Level 1  99999              All industries  Dollars (millions)
# 4      2021  Level 1  99999              All industries  Dollars (millions)
# ...     ...      ...    ...                         ...                 ...
# 41709  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41710  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41711  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41712  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41713  2013  Level 3   ZZ11  Food product manufacturing          Percentage
#
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv',skiprows=[1,2,3])

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41707  2013                     Level 3                 ZZ11
# 41708  2013                     Level 3                 ZZ11
# 41709  2013                     Level 3                 ZZ11
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H07
# 1                  All industries  Dollars (millions)           H08
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv')

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student-dataset.csv', index_col='id')

# %%
df
# Out:
#                   name               nationality                 city  \
# id
# 0            Kiana Lor                     China               Suzhou
# 1       Joshua Lonaker  United States of America        Santa Clarita
# 2        Dakota Blanco  United States of America              Oakland
# 3      Natasha Yarusso  United States of America        Castro Valley
# 4       Brooke Cazares                    Brazil  São José dos Campos
# ..                 ...                       ...                  ...
# 302        Austin Haas  United States of America             Columbus
# 303    Madison Fithian  United States of America          Los Angeles
# 304  Zachary Mulvahill  United States of America          Los Angeles
# 305   Eliana Michelsen  United States of America              Oakland
# 306    Dane Whittemore                    Canada              Toronto
#
#      latitude  longitude gender ethnic.group  age  english.grade  math.grade  \
# id
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student-dataset.csv', index_col='id')

# %%
df
# Out:
#                   name               nationality                 city  \
# id
# 0            Kiana Lor                     China               Suzhou
# 1       Joshua Lonaker  United States of America        Santa Clarita
# 2        Dakota Blanco  United States of America              Oakland
# 3      Natasha Yarusso  United States of America        Castro Valley
# 4       Brooke Cazares                    Brazil  São José dos Campos
# ..                 ...                       ...                  ...
# 302        Austin Haas  United States of America             Columbus
# 303    Madison Fithian  United States of America          Los Angeles
# 304  Zachary Mulvahill  United States of America          Los Angeles
# 305   Eliana Michelsen  United States of America              Oakland
# 306    Dane Whittemore                    Canada              Toronto
#
#      latitude  longitude gender ethnic.group  age  english.grade  math.grade  \
# id
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student-dataset.csv', index_col='name')

# %%
df
# Out:
#                     id               nationality                 city  \
# name
# Kiana Lor            0                     China               Suzhou
# Joshua Lonaker       1  United States of America        Santa Clarita
# Dakota Blanco        2  United States of America              Oakland
# Natasha Yarusso      3  United States of America        Castro Valley
# Brooke Cazares       4                    Brazil  São José dos Campos
# ...                ...                       ...                  ...
# Austin Haas        302  United States of America             Columbus
# Madison Fithian    303  United States of America          Los Angeles
# Zachary Mulvahill  304  United States of America          Los Angeles
# Eliana Michelsen   305  United States of America              Oakland
# Dane Whittemore    306                    Canada              Toronto
#
#                    latitude  longitude gender ethnic.group  age  \
# name
# ...
