# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student_marks.csv')
df
# Out:
#   Unnamed: 0  class Gender         DOB  Maths  Physics  Chemistry  English  \
# 0       John     10      M  05/04/1988     55     45.0         56     87.0
# 1     Suresh     10      M  04/05/1987     75      NaN         78     64.0
# 2     Ramesh     10    NaN  25/05/1989     25     54.0         89      NaN
# 3    Jessica     11    NaN  12/08/1990     78      NaN         86     63.0
# 4   Jennifer     11      F  02/09/1989     58     96.0         78     46.0
# 5       Annu     11      F         NaN     45     87.0         52      NaN
# 6      pooja     12    NaN         NaN     55      NaN         61     58.0
# 7     Ritesh     12      M         NaN     54     76.0         87     56.0
# 8      Farha     12      F  12/08/1990     55     63.0         89     75.0
# 9     Mukesh     12      M  02/09/1989     96     46.0         77     83.0
#
#    Biology  Economics  History  Civics
# 0       21         52       89      65
# 1       90         61       58       2
# ...

# %%
df.loc[0]
# Out:
# Unnamed: 0          John
# class                 10
# Gender                 M
# DOB           05/04/1988
# Maths                 55
# Physics             45.0
# Chemistry             56
# English             87.0
# Biology               21
# Economics             52
# History               89
# Civics                65
# Name: 0, dtype: object

# %%
df.loc[4]
# Out:
# Unnamed: 0      Jennifer
# class                 11
# Gender                 F
# DOB           02/09/1989
# Maths                 58
# Physics             96.0
# Chemistry             78
# English             46.0
# Biology               96
# Economics             77
# History               83
# Civics                53
# Name: 4, dtype: object

# %%
df.loc[[1,4]]
# Out:
#   Unnamed: 0  class Gender         DOB  Maths  Physics  Chemistry  English  \
# 1     Suresh     10      M  04/05/1987     75      NaN         78     64.0
# 4   Jennifer     11      F  02/09/1989     58     96.0         78     46.0
#
#    Biology  Economics  History  Civics
# 1       90         61       58       2
# 4       96         77       83      53

# %%
df.loc[[2,3]]
# Out:
#   Unnamed: 0  class Gender         DOB  Maths  Physics  Chemistry  English  \
# 2     Ramesh     10    NaN  25/05/1989     25     54.0         89      NaN
# 3    Jessica     11    NaN  12/08/1990     78      NaN         86     63.0
#
#    Biology  Economics  History  Civics
# 2       95         87       56      74
# 3       54         89       75      45

# %%
df.loc[3,'class']
# Out:
# 11

# %%
df.loc[0:3,'class']
# Out:
# 0    10
# 1    10
# 2    10
# 3    11
# Name: class, dtype: int64

# %%
df.loc[3:4,'Gender']
# Out:
# 3    NaN
# 4      F
# Name: Gender, dtype: object

# %%
df.loc[df['class']<11]
# Out:
#   Unnamed: 0  class Gender         DOB  Maths  Physics  Chemistry  English  \
# 0       John     10      M  05/04/1988     55     45.0         56     87.0
# 1     Suresh     10      M  04/05/1987     75      NaN         78     64.0
# 2     Ramesh     10    NaN  25/05/1989     25     54.0         89      NaN
#
#    Biology  Economics  History  Civics
# 0       21         52       89      65
# 1       90         61       58       2
# 2       95         87       56      74

# %%
df.loc[df['class']<11,['Maths']]
# Out:
#    Maths
# 0     55
# 1     75
# 2     25

# %%
df.iloc[0]
# Out:
# Unnamed: 0          John
# class                 10
# Gender                 M
# DOB           05/04/1988
# Maths                 55
# Physics             45.0
# Chemistry             56
# English             87.0
# Biology               21
# Economics             52
# History               89
# Civics                65
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#   Unnamed: 0  class Gender         DOB  Maths  Physics  Chemistry  English  \
# 0       John     10      M  05/04/1988     55     45.0         56     87.0
#
#    Biology  Economics  History  Civics
# 0       21         52       89      65

# %%
df.iloc[:,0]
# Out:
# 0        John
# 1      Suresh
# 2      Ramesh
# 3     Jessica
# 4    Jennifer
# 5        Annu
# 6       pooja
# 7      Ritesh
# 8       Farha
# 9      Mukesh
# Name: Unnamed: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#   Unnamed: 0  class Gender         DOB  Maths  Physics  Chemistry  English  \
# 0       John     10      M  05/04/1988     55     45.0         56     87.0
# 1     Suresh     10      M  04/05/1987     75      NaN         78     64.0
#
#    Biology  Economics  History  Civics
# 0       21         52       89      65
# 1       90         61       58       2
