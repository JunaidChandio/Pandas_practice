# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\Fortune1000.csv')
df
# Out:
#                           name                                  industry  \
# 0                      Walmart                     General Merchandisers
# 1                  Exxon Mobil                        Petroleum Refining
# 2                      Chevron                        Petroleum Refining
# 3           Berkshire Hathaway  Insurance: Property and Casualty (Stock)
# 4                        Apple               Computers, Office Equipment
# ..                         ...                                       ...
# 995         Universal American   Health Care: Insurance and Managed Care
# 996                        AAR                     Aerospace and Defense
# 997  Selective Insurance Group  Insurance: Property and Casualty (Stock)
# 998                    Gartner           Information Technology Services
# 999          E*Trade Financial                                Securities
#
#                   sector                           website  rank
# ...

# %%
df.isnull()
# Out:
#       name  industry  sector  website   rank
# 0    False     False   False    False  False
# 1    False     False   False    False  False
# 2    False     False   False    False  False
# 3    False     False   False    False  False
# 4    False     False   False    False  False
# ..     ...       ...     ...      ...    ...
# 995  False     False   False    False  False
# 996  False     False   False    False  False
# 997  False     False   False    False  False
# 998  False     False   False    False  False
# 999  False     False   False    False  False
#
# [1000 rows x 5 columns]

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\Fortune1000.csv')
df
# Out:
#                           name                                  industry  \
# 0                      Walmart                     General Merchandisers
# 1                  Exxon Mobil                        Petroleum Refining
# 2                      Chevron                        Petroleum Refining
# 3           Berkshire Hathaway  Insurance: Property and Casualty (Stock)
# 4                        Apple               Computers, Office Equipment
# ..                         ...                                       ...
# 995         Universal American   Health Care: Insurance and Managed Care
# 996                        AAR                     Aerospace and Defense
# 997  Selective Insurance Group  Insurance: Property and Casualty (Stock)
# 998                    Gartner           Information Technology Services
# 999          E*Trade Financial                                Securities
#
#                   sector                           website    rank
# ...

# %%
df.isnull()
# Out:
#       name  industry  sector  website   rank
# 0    False     False   False    False   True
# 1    False     False   False    False   True
# 2    False     False   False    False   True
# 3    False     False   False    False   True
# 4    False     False   False    False  False
# ..     ...       ...     ...      ...    ...
# 995  False     False   False    False  False
# 996  False     False   False    False  False
# 997  False     False   False    False  False
# 998  False     False   False    False  False
# 999  False     False   False    False  False
#
# [1000 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# name        0
# industry    0
# sector      0
# website     0
# rank        4
# dtype: int64

# %%
df
# Out:
#                           name                                  industry  \
# 0                      Walmart                     General Merchandisers
# 1                  Exxon Mobil                        Petroleum Refining
# 2                      Chevron                        Petroleum Refining
# 3           Berkshire Hathaway  Insurance: Property and Casualty (Stock)
# 4                        Apple               Computers, Office Equipment
# ..                         ...                                       ...
# 995         Universal American   Health Care: Insurance and Managed Care
# 996                        AAR                     Aerospace and Defense
# 997  Selective Insurance Group  Insurance: Property and Casualty (Stock)
# 998                    Gartner           Information Technology Services
# 999          E*Trade Financial                                Securities
#
#                   sector                           website    rank
# ...

# %%
df.isnull().sum()
# Out:
# name        0
# industry    0
# sector      0
# website     0
# rank        4
# dtype: int64

# %%
df
# Out:
#                           name                                  industry  \
# 0                      Walmart                     General Merchandisers
# 1                  Exxon Mobil                        Petroleum Refining
# 2                      Chevron                        Petroleum Refining
# 3           Berkshire Hathaway  Insurance: Property and Casualty (Stock)
# 4                        Apple               Computers, Office Equipment
# ..                         ...                                       ...
# 995         Universal American   Health Care: Insurance and Managed Care
# 996                        AAR                     Aerospace and Defense
# 997  Selective Insurance Group  Insurance: Property and Casualty (Stock)
# 998                    Gartner           Information Technology Services
# 999          E*Trade Financial                                Securities
#
#                   sector                           website    rank
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\Fortune1000.csv')
df
# Out:
#                           name                                  industry  \
# 0                      Walmart                     General Merchandisers
# 1                  Exxon Mobil                        Petroleum Refining
# 2                      Chevron                        Petroleum Refining
# 3           Berkshire Hathaway  Insurance: Property and Casualty (Stock)
# 4                        Apple               Computers, Office Equipment
# ..                         ...                                       ...
# 995         Universal American   Health Care: Insurance and Managed Care
# 996                        AAR                     Aerospace and Defense
# 997  Selective Insurance Group  Insurance: Property and Casualty (Stock)
# 998                    Gartner           Information Technology Services
# 999          E*Trade Financial                                Securities
#
#                   sector                           website    rank
# ...

# %%
df.isnull().sum().sum()
# Out:
# 13

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\Fortune1000.csv')
df
# Out:
#                           name                                  industry  \
# 0                      Walmart                     General Merchandisers
# 1                  Exxon Mobil                        Petroleum Refining
# 2                      Chevron                        Petroleum Refining
# 3           Berkshire Hathaway  Insurance: Property and Casualty (Stock)
# 4                        Apple               Computers, Office Equipment
# ..                         ...                                       ...
# 995         Universal American   Health Care: Insurance and Managed Care
# 996                        AAR                     Aerospace and Defense
# 997  Selective Insurance Group  Insurance: Property and Casualty (Stock)
# 998                    Gartner           Information Technology Services
# 999          E*Trade Financial                                Securities
#
#                   sector                           website    rank
# ...

# %%
df.notnull()
# Out:
#      name  industry  sector  website   rank
# 0    True      True    True     True  False
# 1    True      True    True     True  False
# 2    True      True    True     True  False
# 3    True      True   False     True  False
# 4    True      True   False     True   True
# ..    ...       ...     ...      ...    ...
# 995  True      True    True     True   True
# 996  True      True    True     True   True
# 997  True      True    True     True   True
# 998  True      True    True     True   True
# 999  True      True    True     True   True
#
# [1000 rows x 5 columns]

# %%
df.notnull().sum()
# Out:
# name         996
# industry    1000
# sector       995
# website     1000
# rank         996
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 4987

# %%
import numpy as np

# %%
sr=pd.Series([1,2,3,np.NAN,4,np.NAN])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2
