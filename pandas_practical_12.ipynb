# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student_marks.csv')
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
df.interpolate()
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
df.interpolate(method='linear')
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
df.interpolate(method='time')
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
type(df.DOB[0])
# Out:
# str

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student_marks.csv',parse_dates=['DOB'])
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45         56       87       21
# 1     Suresh      M  04/05/1987     75       96         78       64       90
# 2     Ramesh    NaN  25/05/1989     25       54         89       76       95
# 3    Jessica    NaN  12/08/1990     78       96         86       63       54
# 4   Jennifer      F  02/09/1989     58       96         78       46       96
# 5       Annu      F         NaN     45       87         52       89       55
# 6      pooja    NaN         NaN     55       64         61       58       75
# 7     Ritesh      M         NaN     54       76         87       56       25
# 8      Farha      F  12/08/1990     55       63         89       75       78
# 9     Mukesh      M  02/09/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
type(df.DOB[0])
# Out:
# str

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student_marks.csv',parse_dates=['DOB'],index_col='DOB')
df
# Out:
#            Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  \
# DOB
# 05/04/1988       John      M     55       45         56       87       21
# 04/05/1987     Suresh      M     75       96         78       64       90
# 25/05/1989     Ramesh    NaN     25       54         89       76       95
# 12/08/1990    Jessica    NaN     78       96         86       63       54
# 02/09/1989   Jennifer      F     58       96         78       46       96
# NaN              Annu      F     45       87         52       89       55
# NaN             pooja    NaN     55       64         61       58       75
# NaN            Ritesh      M     54       76         87       56       25
# 12/08/1990      Farha      F     55       63         89       75       78
# 02/09/1989     Mukesh      M     96       46         77       83       58
#
#             Economics  History  Civics
# DOB
# 05/04/1988         52       89      65
# 04/05/1987         61       58       2
# ...

# %%
df.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11148\722817345.py in ?()
# ----> 1 df.interpolate(method='time')
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   11467         limit_area: str | None = None,
#   11468         downcast: str | None = None,
#   11469         **kwargs,
#   11470     ) -> DataFrame | None:
# > 11471         return super().interpolate(
#   11472             method=method,
#   11473             axis=axis,
#   11474             limit=limit,
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7672                     "interpolating."
#    7673                 )
#    7674
# ...

# %%
df
# Out:
#            Unnamed: 0 Gender  Maths  Physics  Chemistry  English  Biology  \
# DOB
# 05/04/1988       John      M     55       45         56       87       21
# 04/05/1987     Suresh      M     75       96         78       64       90
# 25/05/1989     Ramesh    NaN     25       54         89       76       95
# 12/08/1990    Jessica    NaN     78       96         86       63       54
# 02/09/1989   Jennifer      F     58       96         78       46       96
# NaN              Annu      F     45       87         52       89       55
# NaN             pooja    NaN     55       64         61       58       75
# NaN            Ritesh      M     54       76         87       56       25
# 12/08/1990      Farha      F     55       63         89       75       78
# 02/09/1989     Mukesh      M     96       46         77       83       58
#
#             Economics  History  Civics
# DOB
# 05/04/1988         52       89      65
# 04/05/1987         61       58       2
# ...

# %%
df.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11148\722817345.py in ?()
# ----> 1 df.interpolate(method='time')
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   11467         limit_area: str | None = None,
#   11468         downcast: str | None = None,
#   11469         **kwargs,
#   11470     ) -> DataFrame | None:
# > 11471         return super().interpolate(
#   11472             method=method,
#   11473             axis=axis,
#   11474             limit=limit,
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7672                     "interpolating."
#    7673                 )
#    7674
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student_marks.csv',parse_dates=['DOB'])
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45         56       87       21
# 1     Suresh      M  04/05/1987     75       96         78       64       90
# 2     Ramesh    NaN  25/05/1989     25       54         89       76       95
# 3    Jessica    NaN  12/08/1990     78       96         86       63       54
# 4   Jennifer      F  02/09/1989     58       96         78       46       96
# 5       Annu      F         NaN     45       87         52       89       55
# 6      pooja    NaN         NaN     55       64         61       58       75
# 7     Ritesh      M         NaN     54       76         87       56       25
# 8      Farha      F  12/08/1990     55       63         89       75       78
# 9     Mukesh      M  02/09/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
df.interpolate(method='time')
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45         56       87       21
# 1     Suresh      M  04/05/1987     75       96         78       64       90
# 2     Ramesh    NaN  25/05/1989     25       54         89       76       95
# 3    Jessica    NaN  12/08/1990     78       96         86       63       54
# 4   Jennifer      F  02/09/1989     58       96         78       46       96
# 5       Annu      F         NaN     45       87         52       89       55
# 6      pooja    NaN         NaN     55       64         61       58       75
# 7     Ritesh      M         NaN     54       76         87       56       25
# 8      Farha      F  12/08/1990     55       63         89       75       78
# 9     Mukesh      M  02/09/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45         56       87       21
# 1     Suresh      M  04/05/1987     75       96         78       64       90
# 2     Ramesh    NaN  25/05/1989     25       54         89       76       95
# 3    Jessica    NaN  12/08/1990     78       96         86       63       54
# 4   Jennifer      F  02/09/1989     58       96         78       46       96
# 5       Annu      F         NaN     45       87         52       89       55
# 6      pooja    NaN         NaN     55       64         61       58       75
# 7     Ritesh      M         NaN     54       76         87       56       25
# 8      Farha      F  12/08/1990     55       63         89       75       78
# 9     Mukesh      M  02/09/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\Class_List.csv')
df
# Out:
#    Course ID|"Student ID"#This line may not be altered.
# 0                      Spring2022-ART120-01|"0001015"
# 1                      Spring2022-ART120-01|"0001035"
# 2                      Spring2022-ART120-01|"0001011"
# 3                      Spring2022-ART120-01|"0001017"
# 4                      Spring2022-ART120-01|"0001023"
# ..                                                ...
# 73                     Spring2022-POL420-01|"0001019"
# 74                     Spring2022-POL420-01|"0001009"
# 75                     Spring2022-POL420-01|"0001005"
# 76                     Spring2022-POL420-01|"0001023"
# 77                     Spring2022-POL420-01|"0001015"
#
# [78 rows x 1 columns]

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student_marks.csv',parse_dates=['DOB'],index_col=0)
df
# Out:
#          Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# John          M  05/04/1988     55       45         56       87       21
# Suresh        M  04/05/1987     75       96         78       64       90
# Ramesh      NaN  25/05/1989     25       54         89       76       95
# Jessica     NaN  12/08/1990     78       96         86       63       54
# Jennifer      F  02/09/1989     58       96         78       46       96
# Annu          F         NaN     45       87         52       89       55
# pooja       NaN         NaN     55       64         61       58       75
# Ritesh        M         NaN     54       76         87       56       25
# Farha         F  12/08/1990     55       63         89       75       78
# Mukesh        M  02/09/1989     96       46         77       83       58
#
#           Economics  History  Civics
# John             52       89      65
# Suresh           61       58       2
# Ramesh           87       56      74
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student_marks.csv',parse_dates=['DOB'],index_col='class')
df
# Out:
#       Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  \
# class
# 10          John      M  05/04/1988     55       45         56       87
# 10        Suresh      M  04/05/1987     75       96         78       64
# 10        Ramesh    NaN  25/05/1989     25       54         89       76
# 11       Jessica    NaN  12/08/1990     78       96         86       63
# 11      Jennifer      F  02/09/1989     58       96         78       46
# 11          Annu      F         NaN     45       87         52       89
# 12         pooja    NaN         NaN     55       64         61       58
# 12        Ritesh      M         NaN     54       76         87       56
# 12         Farha      F  12/08/1990     55       63         89       75
# 12        Mukesh      M  02/09/1989     96       46         77       83
#
#        Biology  Economics  History  Civics
# class
# 10          21         52       89      65
# 10          90         61       58       2
# ...

# %%
df.interpolate(method='index')
# Out:
#       Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  \
# class
# 10          John      M  05/04/1988     55       45         56       87
# 10        Suresh      M  04/05/1987     75       96         78       64
# 10        Ramesh    NaN  25/05/1989     25       54         89       76
# 11       Jessica    NaN  12/08/1990     78       96         86       63
# 11      Jennifer      F  02/09/1989     58       96         78       46
# 11          Annu      F         NaN     45       87         52       89
# 12         pooja    NaN         NaN     55       64         61       58
# 12        Ritesh      M         NaN     54       76         87       56
# 12         Farha      F  12/08/1990     55       63         89       75
# 12        Mukesh      M  02/09/1989     96       46         77       83
#
#        Biology  Economics  History  Civics
# class
# 10          21         52       89      65
# 10          90         61       58       2
# ...

# %%
df.interpolate(method='nearest')
# Out:
#       Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  \
# class
# 10          John      M  05/04/1988     55       45         56       87
# 10        Suresh      M  04/05/1987     75       96         78       64
# 10        Ramesh    NaN  25/05/1989     25       54         89       76
# 11       Jessica    NaN  12/08/1990     78       96         86       63
# 11      Jennifer      F  02/09/1989     58       96         78       46
# 11          Annu      F         NaN     45       87         52       89
# 12         pooja    NaN         NaN     55       64         61       58
# 12        Ritesh      M         NaN     54       76         87       56
# 12         Farha      F  12/08/1990     55       63         89       75
# 12        Mukesh      M  02/09/1989     96       46         77       83
#
#        Biology  Economics  History  Civics
# class
# 10          21         52       89      65
# 10          90         61       58       2
# ...

# %%
df=pd.read_csv('C:\\Users\\Junaid Ahmed\\Downloads\\student_marks.csv',parse_dates=['DOB'],index_col='DOB')
df
# Out:
#            Unnamed: 0  class Gender  Maths  Physics  Chemistry  English  \
# DOB
# 05/04/1988       John     10      M     55       45         56       87
# 04/05/1987     Suresh     10      M     75       96         78       64
# 25/05/1989     Ramesh     10    NaN     25       54         89       76
# 12/08/1990    Jessica     11    NaN     78       96         86       63
# 02/09/1989   Jennifer     11      F     58       96         78       46
# NaN              Annu     11      F     45       87         52       89
# NaN             pooja     12    NaN     55       64         61       58
# NaN            Ritesh     12      M     54       76         87       56
# 12/08/1990      Farha     12      F     55       63         89       75
# 02/09/1989     Mukesh     12      M     96       46         77       83
#
#             Biology  Economics  History  Civics
# DOB
# 05/04/1988       21         52       89      65
# 04/05/1987       90         61       58       2
# ...

# %%
#df.interpolate(method='polynomial',order=2)
